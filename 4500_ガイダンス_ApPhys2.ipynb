# %% [markdown]
# <a href="https://colab.research.google.com/github/kzhkAKT/ApPhys2A/blob/draft2026/4500_%E3%82%AC%E3%82%A4%E3%83%80%E3%83%B3%E3%82%B9_ApPhys2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Syllabus
#
# ## 4C 応用物理ⅡA
# 1. [マテリアル・プロセス工学コース](https://syllabus.kosen-k.go.jp/Pages/PublicSyllabus?school_id=08&department_id=35&subject_id=0014&year=2022&lang=ja), [PDF](https://drive.google.com/file/d/1XhaQYIauO5bRnNXwNO0oFFNaF5dnVPvJ/view?usp=classroom_web&authuser=0)
# 2. [バイオ・アグリ工学コース](https://syllabus.kosen-k.go.jp/Pages/PublicSyllabus?school_id=08&department_id=36&subject_id=0014&year=2022&lang=ja), [PDF](https://drive.google.com/file/d/1kwM39yteCTDT_k0rFeYavxw8jcRzqPLx/view?usp=classroom_web&authuser=0)
#
# ## 4B 応用物理ⅡA
# 1. [土防災システムコース](https://syllabus.kosen-k.go.jp/Pages/PublicSyllabus?school_id=08&department_id=37&subject_id=0028&year=2022&lang=ja), [PDF](https://drive.google.com/file/d/1lmGqWSmeDQFUlOSWE8RcautggGeFeZpS/view?usp=classroom_web&authuser=0)
# 2. [空間デザインコース](https://syllabus.kosen-k.go.jp/Pages/PublicSyllabus?school_id=08&department_id=38&subject_id=0026&year=2022&lang=ja), [PDF](https://drive.google.com/file/d/1QowfX50vpVRCD5P_a4f9CwlBvpKyZ08Y/view?usp=classroom_web&authuser=0)
#
# ### 学年総合成績
#
# - 0.4×(中間試験結果)＋0.4×(前期末試験結果)＋0.18×(平素の成績)+ 0.02×(姿勢)
# - 再試験は行いません。

# %% [markdown]
# ## 教材

# %% [markdown]
# - 教科書：高専テキストシリーズ「物理 (下) 熱・電磁気・原子」 潮 秀樹 監修，大野秀樹 他 編集，森北出版
#
# - 問題集：高専テキストシリーズ「物理問題集」 潮 秀樹 監修，大野秀樹 他 編集， 森北出版
# - 真緑色の問題集
#   - 資料集：「フォトサイエンス 物理図録」数研出版編集部 編， 数研出版 その他：必要に応じて，自製プリント等を配布

# %% [markdown]
# ### 学習済み内容/物理III

# %% [markdown]
# 4 電気と磁気
#  - 4.1 静電気力
#   - 4.1.1 带電
#    - 4.1.2 クーロンの法則
#  - 4.2 電界とガウスの法則
#    - 4.2.1 電界
#    - 4.2.2 電気力線
#    - 4.2.3 ガウスの法則
#  - 4.3 電位
#    - 4.3.1 電位と電位差
#    - 4.3.2 等電位面
#    - 4.3.3 導体と静電誘導
#    - 4.3.4 靜電遮蔽
#    - 4.4 コンデンサー
#    - 4.4.1 コンデンサーと電気容量
#    - 4.4.2 誘電体と誘電分極
#    - 4.4.3 コンデンサーの接続
#    - 4.4.4 コンデンサーのエネルギー

# %%
#@title 帯電
# %%html
<iframe src="https://phet.colorado.edu/sims/html/john-travoltage/latest/john-travoltage_en.html"
        width="800"
        height="600"
        allowfullscreen>
</iframe>
# Out:
# <iframe src="https://phet.colorado.edu/sims/html/john-travoltage/latest/john-travoltage_en.html"
#         width="800"
#         height="600"
#         allowfullscreen>
# </iframe>

# %%
#@title クーロン力
# %%html
<iframe src="https://phet.colorado.edu/sims/html/coulombs-law/latest/coulombs-law_en.html"
        width="800"
        height="600"
        allowfullscreen>
</iframe>
# Out:
# <iframe src="https://phet.colorado.edu/sims/html/coulombs-law/latest/coulombs-law_en.html"
#         width="800"
#         height="600"
#         allowfullscreen>
# </iframe>

# %%
#@title 電界と電位
# %%html
<iframe src="https://phet.colorado.edu/sims/html/charges-and-fields/latest/charges-and-fields_en.html"
        width="800"
        height="600"
        allowfullscreen>
</iframe>
# Out:
# <iframe src="https://phet.colorado.edu/sims/html/charges-and-fields/latest/charges-and-fields_en.html"
#         width="800"
#         height="600"
#         allowfullscreen>
# </iframe>

# %%
#@title 水流の吹き出し
# %%html
<iframe width="560" height="315" src="https://www.youtube-nocookie.com/embed/YtSy1yUkDE0?si=iMU3Zkoi-nChLjuD" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube-nocookie.com/embed/YtSy1yUkDE0?si=iMU3Zkoi-nChLjuD" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

# %%
#@title 水流の吸い込み
# %%html
<iframe width="560" height="315" src="https://www.youtube-nocookie.com/embed/m4yy0U_fHNk?si=ROPn5eK86KEUcqCH" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube-nocookie.com/embed/m4yy0U_fHNk?si=ROPn5eK86KEUcqCH" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

# %%
#@title 帯電と分極
# %%html
<iframe src="https://phet.colorado.edu/sims/html/balloons-and-static-electricity/latest/balloons-and-static-electricity_en.html"
        width="800"
        height="600"
        allowfullscreen>
</iframe>
# Out:
# <iframe src="https://phet.colorado.edu/sims/html/balloons-and-static-electricity/latest/balloons-and-static-electricity_en.html"
#         width="800"
#         height="600"
#         allowfullscreen>
# </iframe>

# %%
#@title コンデンサの動作確認
# %%html
<iframe src="https://phet.colorado.edu/sims/html/capacitor-lab-basics/latest/capacitor-lab-basics_en.html"
        width="800"
        height="600"
        allowfullscreen>
</iframe>
# Out:
# <iframe src="https://phet.colorado.edu/sims/html/capacitor-lab-basics/latest/capacitor-lab-basics_en.html"
#         width="800"
#         height="600"
#         allowfullscreen>
# </iframe>

# %% [markdown]
# ### 水流モデルと電磁気学

# %% [markdown]
# - 水流モデルと電磁気学のアナロジーを利用すると、ある程度視覚的に電気学を理解でします。
# - しかし、アナロジーが通じない部分もあるのでそこをよく理解してください。(特に電磁誘導)

# %%
#@title 電流の水流モデル
# %%html
<iframe width="560" height="315" src="https://www.youtube-nocookie.com/embed/YK3tSdC9xvM?si=RSrZKndjmAwfS6CM" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube-nocookie.com/embed/YK3tSdC9xvM?si=RSrZKndjmAwfS6CM" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

# %% [markdown]
# ## この講義で学もの

# %% [markdown]
# - 4.5 電流と電圧
#     - 4.5.1 電流
#     - 4.5.2 オームの法則
#     - 4.5.3 電力とジュール熱
# - 4.6 直流回路
#     - 4.6.1抵抗の接続
#     - 4.6.2 電池の起電力と内部抵抗
#     - 4.6.3 電流計と電圧計
#     - 4.6.4 キルヒホッフの法則
#
# - 4.7 電流と磁界
#     - 4.7.1 磁石による磁界
#     - 4.7.2 電流による磁界
#     - 4.7.3 電流が磁界から受ける力
# - 4.8 電磁誘導と交流
#     - 4.8.1 電磁誘導
#     - 4.8.2 交流
#
# - 4.9 電磁波
#     - 4.9.1 電気振動
#     - 4.9.2 変動する電磁界と電磁波の発生
#     - 4.9.3 電磁波の種類 章末問題

# %% [markdown]
# ## 到達目標

# %% [markdown]
# 0. 静電気力とコンデンサの復習
# 1. キルヒホッフの法則を用いて，簡単な直流回路やコンデンサーを含む電流回路での電流・電荷・電圧を計算して求めることができる。
# 2. 直線電流の作る磁界をイメージできる。また，その磁界が他の直線電流に及ぼす力を定性的・定量的に評価できる。
# 3. 電磁誘導のメカニズム(レンツの法則・ファラデーの法則)を説明できる。
# 4. 簡単な交流回路において電荷・電流・電圧を求めることができる。

# %% [markdown]
# ## 課題

# %% [markdown]
# - [演習課題の取り組みと提出に関するご案内](https://docs.google.com/document/d/1hGTJp3iFv9qXW8uwJfdR8IE8u2OMM6LvZac3UxtL3pg/edit?usp=sharing)
# - [講義用アプリ導入初期設定ガイド](https://docs.google.com/document/d/1uklgRufu7DcSTEe3iPuhc5eszEM1I-TD1psl6F-ReGY/edit?usp=sharing)

# %% [markdown]
# # 物理学習上のイメージ

# %%
# @title 和食作成３倍速
# %%html
<iframe width="560" height="315" src="https://www.youtube-nocookie.com/embed/STxpxgpBOYg?si=hvce5YrrJjgS3w-c" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube-nocookie.com/embed/STxpxgpBOYg?si=hvce5YrrJjgS3w-c" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

# %% [markdown]
# 和食作成で身につけた、包丁使いや調理方法は、他の料理(イタリアン、中華)などで利用できます。
# - 料理動画を全て閲覧する必要はありません
#   1. 準備
#   1. 調理
#   1. 盛付け
#   1. 食事
#
# と順序立て料理が作られていることと、物理の学習にanalogyを持たています。

# %%
#@title プラモデル作成(タイムプラス)
# %%html
<iframe width="560" height="315" src="https://www.youtube-nocookie.com/embed/Ey24Lv2Aq6E?si=ZAxVRNuyZyORZw4S" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube-nocookie.com/embed/Ey24Lv2Aq6E?si=ZAxVRNuyZyORZw4S" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

# %% [markdown]
# 物理との analogy:
# 一つ一つの考え(パーツ)を組み立てて、全体像(ガンプラ)を構築する。

# %% [markdown]
# ## 覚えるのではなく、観察して組み立てる

# %% [markdown]
# <a href="https://drive.google.com/file/d/17KFrnjMj07vEYsJQ2AWPKadMrgw6SgB0/view?usp=sharing" target="_blank">
#   <img src="https://drive.google.com/uc?export=view&id=17KFrnjMj07vEYsJQ2AWPKadMrgw6SgB0"
#        style="width: 50%; max-width: 600px; height: auto; display: block; margin: 0 auto;"
#        alt="クリックして拡大">
# </a>

# %% [markdown]
# <a href="https://drive.google.com/file/d/1oVuVyMb5vUeCNAYKWxIYMlr_2zKYRfzq/view?usp=sharing" target="_blank">
#   <img src="https://drive.google.com/uc?export=view&id=1oVuVyMb5vUeCNAYKWxIYMlr_2zKYRfzq"
#        style="width: 50%; max-width: 600px; height: auto; display: block; margin: 0 auto;"
#        alt="クリックして拡大">
# </a>
