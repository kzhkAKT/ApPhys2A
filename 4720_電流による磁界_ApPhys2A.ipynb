# %% [markdown]
# # 4.7 電流と磁界

# %% [markdown]
# - 4.7.1 磁石による磁界
# - **4.7.2 電流による磁界**
# - 4.7.3 電流が磁界から受ける力

# %% [markdown]
# ## 4.7.2 電流による磁界

# %% [markdown]
# [Hans Christian Ørsted](https://en.wikipedia.org/wiki/Hans_Christian_%C3%98rsted)
#
# ![](https://upload.wikimedia.org/wikipedia/commons/c/c8/Hans_Christian_%C3%98rsted_som_ung.jpg)
# ![](https://upload.wikimedia.org/wikipedia/commons/c/cf/Hans_Christian_%C3%98rsted_daguerreotype.jpg)

# %%
# @title Ørsted が発見当初行っていた実験の再現
# %%html
<iframe width="560" height="315" src="https://www.youtube-nocookie.com/embed/fCIjKZXmaU8?si=_qz6qmdQal0cf8Kn" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube-nocookie.com/embed/fCIjKZXmaU8?si=_qz6qmdQal0cf8Kn" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

# %%
# @title 電流の流れによる電気力線の変化
# %%html
<iframe width="560" height="315" src="https://www.youtube-nocookie.com/embed/mxwevNEa2vs?si=Opuw1A6auBQpv_Ce" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube-nocookie.com/embed/mxwevNEa2vs?si=Opuw1A6auBQpv_Ce" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

# %% [markdown]
# ### (1) 直流電流による磁界

# %% [markdown]
# 以下では
#
#
# *   電流の大きさ $I$
# *   磁界の大きさ $H$
#
# とします。

# %%
# @title 実験) 直流電流による磁界
# %%html
<iframe width="560" height="315" src="https://www.youtube-nocookie.com/embed/caHXwJbkbQU?si=01TdfBb14mTR7703" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube-nocookie.com/embed/caHXwJbkbQU?si=01TdfBb14mTR7703" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

# %% [markdown]
# <img src="https://jeea.or.jp/course/contents/12134/image/diagram/01_big.gif" width="320">
#
# \begin{align*}
# \require{bbox}
# \bbox[lightgray,1px]{H = \dfrac{I}{2 \pi r}}
# \end{align*}
#
# 考え方
# - $I = (2\pi r) H$
#
# ---
#
# 参考サイト https://jeea.or.jp/course/contents/12134/

# %% [markdown]
# ![](http://hyperphysics.phy-astr.gsu.edu/hbase/magnetic/imgmag/magcur.gif)

# %% [markdown]
# ### (2) 円形電流の中心磁界

# %%
# @title 実験) 円形電流の中心磁界
# %%html
<iframe width="560" height="315" src="https://www.youtube-nocookie.com/embed/cycRAQkije8?si=ux4QFXzQycXJr67A" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube-nocookie.com/embed/cycRAQkije8?si=ux4QFXzQycXJr67A" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

# %% [markdown]
# \begin{align*}
# \require{bbox}
# \bbox[lightgray,1px]{H = \dfrac{I}{2r}}
# \end{align*}
#
# 考え方
# - リング状になると $\pi$ が消えていることに注意してください。

# %% [markdown]
# ### (3) ソレノイド内部の磁界

# %%
#@title 実験1/2) ソレノイド内部の磁界
# %%html
<iframe width="560" height="315" src="https://www.youtube-nocookie.com/embed/FzPO92Jxxt8?si=_6G2dVH6XH3GhMnQ" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube-nocookie.com/embed/FzPO92Jxxt8?si=_6G2dVH6XH3GhMnQ" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

# %%
#@title 実験2/2) ソレノイド内部の磁界
# %%html
<iframe width="560" height="315" src="https://www.youtube-nocookie.com/embed/V-M07N4a6-Y?si=E573m3Z4o8lRu81e" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube-nocookie.com/embed/V-M07N4a6-Y?si=E573m3Z4o8lRu81e" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

# %% [markdown]
# \begin{align*}
# \require{bbox}
# \bbox[lightgray,5px]{H = n\,I}
# \end{align*}

# %% [markdown]
# 考え方
# - リングが複数重なると、半径 $r$ の影響が消えて、巻き数 $n$ に比例する

# %% [markdown]
# ## 発展的内容: ビオ・サバールの法則

# %% [markdown]
# 進学予定者がいる可能性があるので、ここで紹介した磁界はビオ・サバールの法則を理解すると、  導出可能であることを伝えておきます。

# %% [markdown]
# 関連リンク
#
# * https://ja.wikipedia.org/wiki/%E3%83%93%E3%82%AA%E3%83%BB%E3%82%B5%E3%83%90%E3%83%BC%E3%83%AB%E3%81%AE%E6%B3%95%E5%89%87
# * http://fnorio.com/0094Biot-Savart_law1/Biot-Savart_law1.html
